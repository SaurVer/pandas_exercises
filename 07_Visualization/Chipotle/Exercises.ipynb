# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo= pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
top_items=chipo.groupby('item_name')['quantity'].sum().sort_values(ascending=False).head(5).to_dict()

# %%
fig= plt.figure(figsize=(10,5))
plt.bar(top_items.keys(), top_items.values(),color= 'cyan')
plt.title('Top items sold')
plt.xlabel('items')
plt.ylabel('number of items sold')

plt.xticks(rotation= 25)
plt.tight_layout()
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
items_order_for_price=chipo.groupby('item_price')['quantity'].sum().sort_values(ascending=False).to_dict()
items_order_for_price
# Out:
# {'$8.75 ': 730,
#  '$11.25 ': 521,
#  '$9.25 ': 398,
#  '$4.45 ': 349,
#  '$8.49 ': 311,
#  '$11.75 ': 284,
#  '$1.25 ': 264,
#  '$8.99 ': 246,
#  '$2.15 ': 192,
#  '$2.95 ': 174,
#  '$1.50 ': 117,
#  '$1.09 ': 106,
#  '$2.39 ': 100,
#  '$10.98 ': 99,
#  '$1.69 ': 99,
#  '$3.99 ': 98,
#  '$17.50 ': 80,
#  '$2.50 ': 54,
#  '$6.49 ': 53,
#  '$11.48 ': 51,
#  '$3.39 ': 45,
#  '$2.18 ': 44,
#  '$8.90 ': 40,
#  '$16.98 ': 38,
#  '$4.30 ': 34,
#  '$22.50 ': 26,
#  '$11.89 ': 26,
#  '$18.50 ': 24,
#  '$3.75 ': 21,
#  '$21.96 ': 20,
#  '$3.00 ': 19,
#  '$8.69 ': 19,
#  '$9.39 ': 17,
#  '$5.90 ': 16,
#  '$44.25 ': 15,
#  '$8.19 ': 14,
#  '$17.98 ': 14,
#  '$4.50 ': 12,
#  '$23.50 ': 12,
#  '$5.00 ': 12,
#  '$7.40 ': 11,
#  '$15.00 ': 10,
#  '$11.08 ': 10,
#  '$26.25 ': 9,
#  '$6.00 ': 8,
#  '$13.52 ': 8,
#  '$35.00 ': 8,
#  '$10.50 ': 7,
#  '$3.89 ': 6,
#  '$27.75 ': 6,
#  '$3.27 ': 6,
#  '$4.78 ': 6,
#  '$7.17 ': 6,
#  '$10.58 ': 5,
#  '$7.50 ': 5,
#  '$6.78 ': 4,
#  '$23.78 ': 4,
# ...

# %%
plt.figure(figsize=(25,5))
plt.scatter(x=items_order_for_price.keys(), y= items_order_for_price.values(), color= 'y')
plt.xticks(rotation=90)
plt.title(' items sold')
plt.xlabel('price point')
plt.ylabel('number of items sold')
# Out:
# Text(0, 0.5, 'number of items sold')

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.

# %%
# create 2 plots and show above 2 answers combined

fig=plt.figure()
ax1=fig.add_subplot(2,1,1)
ax2=fig.add_subplot(2,1,2)

_ =ax1.bar(top_items.keys(), top_items.values(),color= 'cyan')
ax2.scatter(x=list(items_order_for_price.keys()), y= list(items_order_for_price.values()), color= 'y')

# %%
items_order_for_price.keys()
# Out:
# dict_keys(['$8.75 ', '$11.25 ', '$9.25 ', '$4.45 ', '$8.49 ', '$11.75 ', '$1.25 ', '$8.99 ', '$2.15 ', '$2.95 ', '$1.50 ', '$1.09 ', '$2.39 ', '$10.98 ', '$1.69 ', '$3.99 ', '$17.50 ', '$2.50 ', '$6.49 ', '$11.48 ', '$3.39 ', '$2.18 ', '$8.90 ', '$16.98 ', '$4.30 ', '$22.50 ', '$11.89 ', '$18.50 ', '$3.75 ', '$21.96 ', '$3.00 ', '$8.69 ', '$9.39 ', '$5.90 ', '$44.25 ', '$8.19 ', '$17.98 ', '$4.50 ', '$23.50 ', '$5.00 ', '$7.40 ', '$15.00 ', '$11.08 ', '$26.25 ', '$6.00 ', '$13.52 ', '$35.00 ', '$10.50 ', '$3.89 ', '$27.75 ', '$3.27 ', '$4.78 ', '$7.17 ', '$10.58 ', '$7.50 ', '$6.78 ', '$23.78 ', '$22.16 ', '$11.80 ', '$8.50 ', '$17.80 ', '$4.36 ', '$26.07 ', '$22.20 ', '$6.45 ', '$2.29 ', '$5.07 ', '$13.35 ', '$35.25 ', '$33.75 ', '$32.94 ', '$12.98 ', '$7.98 ', '$4.00 ', '$22.96 ', '$16.38 ', '$11.49 ', '$1.99 '])

# %%
chipo.item_price = [float(value[1:-1]) for value in chipo.item_price] # strip the dollar sign and trailing space

# then groupby the orders and sum
orders = chipo.groupby('order_id').sum()

# %%
orders
# Out:
#           quantity                                          item_name  \
# order_id
# 1                4  Chips and Fresh Tomato SalsaIzzeNantucket Nect...
# 2                2                                       Chicken Bowl
# 3                2                          Chicken BowlSide of Chips
# 4                2                      Steak BurritoSteak Soft Tacos
# 5                2                   Steak BurritoChips and Guacamole
# ...            ...                                                ...
# 1830             2                        Steak BurritoVeggie Burrito
# 1831             3                    Carnitas BowlChipsBottled Water
# 1832             2              Chicken Soft TacosChips and Guacamole
# 1833             2                         Steak BurritoSteak Burrito
# 1834             3  Chicken Salad BowlChicken Salad BowlChicken Sa...
#
#                                          choice_description  item_price
# order_id
# ...

# %%
plt.scatter(x = orders.item_price, y = orders.quantity, s = 50, c = 'green')

# Set the title and labels
plt.xlabel('Order Price')
plt.ylabel('Items ordered')
plt.title('Number of items ordered per order price')
plt.ylim(0)
# Out:
# (0.0, 36.7)
