# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips= pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv',)

# %%
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips.drop(columns='Unnamed: 0', inplace=True)

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
sns.distplot(tips.total_bill)
plt.title('total bill frequency')
plt.xlabel('total_bill')
plt.ylabel('frequency')
# Out:
# /var/folders/jm/7qcz1nys2_l6rk66dc2f48wc0000gn/T/ipykernel_5627/4205424376.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips.total_bill)
# Text(0, 0.5, 'frequency')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
ax=sns.jointplot(x=tips.total_bill, y= tips.tip)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a FacetGrid with one joint plot per day
g = sns.FacetGrid(tips, col='day', col_wrap=2)
g.map(sns.scatterplot, 'total_bill', 'tip')

# Set labels and title for each subplot
for ax in g.axes.flat:
    ax.set_xlabel('Total Bill')
    ax.set_ylabel('Tip')
    # ax.set_title(ax.get_title().split('=')[-1])  # Extract day from subplot title

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
sns.scatterplot(x=tips.total_bill, y= tips.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
g= sns.FacetGrid(col='day', data=tips, col_wrap=2)
g.map(sns.scatterplot, 'tip', 'total_bill')

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
fig= plt.figure()
ax = fig.add_subplot(111, projection='3d')
props= {}
ax.scatter(tips.total_bill, tips.tip, tips.size)

# %%
sns.pairplot(tips)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.stripplot(x=tips.day, y= tips.total_bill, jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x = "day", y = "total_bill", data = tips, jitter = True, hue='day');

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.stripplot(x= 'tip', y='day', data=tips, hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(x='day',y='total_bill',data= tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x=tips.day,y=tips.total_bill, hue= tips.time)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
g= sns.FacetGrid(col= 'time', col_wrap=2, data=tips)
g.map(sns.histplot,'tip' )

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
g= sns.FacetGrid(col= 'sex', col_wrap=2, data= tips, hue='smoker')
g.map(sns.scatterplot,'total_bill', 'tip' )

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %%
import matplotlib.pyplot as plt

# Assuming tips is your DataFrame and you want to add a hue based on the 'day' column
plt.scatter(tips['total_bill'], tips['tip'], c=tips['day'].astype('category').cat.codes, cmap='Set1')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Scatter Plot with Hue')
plt.colorbar(label='Day')
plt.show()

# %%
# c is color
